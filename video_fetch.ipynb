# %%
pip install mediapipe
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 1.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 3.4 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/104.6 kB ? eta -:--:--
#      -------------------------------------- 104.6/104.6 kB 5.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/51.0 MB ? eta -:--:--
#     --------------------------------------- 0.9/51.0 MB 18.3 MB/s eta 0:00:03
#    - -------------------------------------- 2.5/51.0 MB 26.4 MB/s eta 0:00:02
#    --- ------------------------------------ 4.6/51.0 MB 32.5 MB/s eta 0:00:02
#    ----- ---------------------------------- 6.8/51.0 MB 35.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 7.1/51.0 MB 32.5 MB/s eta 0:00:02
# ...
